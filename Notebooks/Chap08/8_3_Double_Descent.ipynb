# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirui-peng/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-jesfrbo2
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-jesfrbo2
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=b18d038b4c700534975b693e55dba742c571340ca59af22d9f83b508c9de7175
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a5r_nz4x/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.291315, train error 87.50,  test loss 2.297057, test error 88.57
# Epoch   100, train loss 1.925928, train error 72.15,  test loss 1.779731, test error 70.45
# Epoch   200, train loss 1.911365, train error 71.88,  test loss 1.753769, test error 70.32
# Epoch   300, train loss 1.906513, train error 71.50,  test loss 1.748437, test error 69.80
# Epoch   400, train loss 1.909189, train error 71.90,  test loss 1.739983, test error 70.10
# Epoch   500, train loss 1.903867, train error 71.60,  test loss 1.747500, test error 68.95
# Epoch   600, train loss 1.904831, train error 71.50,  test loss 1.742447, test error 69.88
# Epoch   700, train loss 1.904384, train error 71.65,  test loss 1.747813, test error 70.50
# Epoch   800, train loss 1.903187, train error 70.82,  test loss 1.743400, test error 69.15
# Epoch   900, train loss 1.904646, train error 71.55,  test loss 1.743045, test error 70.18
# Training model with   4 hidden variables
# Epoch     0, train loss 2.232594, train error 83.93,  test loss 2.221764, test error 83.80
# Epoch   100, train loss 1.770965, train error 65.03,  test loss 1.618047, test error 63.40
# Epoch   200, train loss 1.717029, train error 63.53,  test loss 1.546029, test error 59.95
# Epoch   300, train loss 1.692109, train error 62.53,  test loss 1.536364, test error 59.60
# Epoch   400, train loss 1.685164, train error 61.83,  test loss 1.527494, test error 59.17
# Epoch   500, train loss 1.678584, train error 61.47,  test loss 1.529665, test error 59.35
# Epoch   600, train loss 1.680159, train error 61.67,  test loss 1.520890, test error 58.78
# Epoch   700, train loss 1.671238, train error 61.40,  test loss 1.519855, test error 59.17
# Epoch   800, train loss 1.670673, train error 61.22,  test loss 1.509674, test error 58.35
# Epoch   900, train loss 1.666446, train error 61.20,  test loss 1.518807, test error 58.55
# Training model with   6 hidden variables
# Epoch     0, train loss 2.247097, train error 84.03,  test loss 2.228336, test error 82.55
# Epoch   100, train loss 1.689723, train error 61.50,  test loss 1.534532, test error 59.90
# Epoch   200, train loss 1.660463, train error 59.47,  test loss 1.512648, test error 59.45
# Epoch   300, train loss 1.652757, train error 58.80,  test loss 1.516199, test error 59.45
# Epoch   400, train loss 1.647237, train error 58.83,  test loss 1.506034, test error 58.45
# Epoch   500, train loss 1.644629, train error 58.10,  test loss 1.501554, test error 59.25
# Epoch   600, train loss 1.635045, train error 58.12,  test loss 1.478667, test error 57.75
# Epoch   700, train loss 1.630682, train error 57.75,  test loss 1.475412, test error 57.40
# Epoch   800, train loss 1.637900, train error 58.03,  test loss 1.485757, test error 57.70
# Epoch   900, train loss 1.632045, train error 57.80,  test loss 1.478317, test error 57.60
# Training model with   8 hidden variables
# Epoch     0, train loss 2.194493, train error 81.07,  test loss 2.156907, test error 79.30
# Epoch   100, train loss 1.569661, train error 54.50,  test loss 1.434763, test error 53.85
# Epoch   200, train loss 1.527157, train error 52.95,  test loss 1.390730, test error 51.58
# Epoch   300, train loss 1.499534, train error 51.28,  test loss 1.356037, test error 49.62
# Epoch   400, train loss 1.480750, train error 50.80,  test loss 1.327250, test error 50.22
# Epoch   500, train loss 1.471851, train error 50.30,  test loss 1.319346, test error 49.15
# Epoch   600, train loss 1.463358, train error 49.75,  test loss 1.323451, test error 49.10
# Epoch   700, train loss 1.462883, train error 50.22,  test loss 1.328001, test error 48.58
# Epoch   800, train loss 1.458438, train error 49.83,  test loss 1.351219, test error 49.30
# Epoch   900, train loss 1.452447, train error 49.70,  test loss 1.343556, test error 49.60
# Training model with  10 hidden variables
# Epoch     0, train loss 2.295270, train error 89.35,  test loss 2.302958, test error 90.47
# Epoch   100, train loss 1.567845, train error 54.45,  test loss 1.480262, test error 54.12
# Epoch   200, train loss 1.501561, train error 52.53,  test loss 1.420485, test error 52.47
# Epoch   300, train loss 1.461918, train error 50.17,  test loss 1.406934, test error 51.60
# Epoch   400, train loss 1.441387, train error 49.80,  test loss 1.405381, test error 51.33
# Epoch   500, train loss 1.432139, train error 49.72,  test loss 1.418663, test error 51.45
# Epoch   600, train loss 1.429059, train error 49.80,  test loss 1.433405, test error 52.05
# Epoch   700, train loss 1.419563, train error 49.70,  test loss 1.430934, test error 51.40
# Epoch   800, train loss 1.417970, train error 49.40,  test loss 1.438593, test error 52.03
# Epoch   900, train loss 1.412635, train error 49.22,  test loss 1.449657, test error 52.22
# Training model with  14 hidden variables
# Epoch     0, train loss 2.239236, train error 83.70,  test loss 2.227470, test error 83.03
# Epoch   100, train loss 1.456436, train error 49.05,  test loss 1.382854, test error 51.42
# Epoch   200, train loss 1.358380, train error 45.40,  test loss 1.342670, test error 49.25
# Epoch   300, train loss 1.325083, train error 44.95,  test loss 1.344436, test error 48.85
# Epoch   400, train loss 1.297754, train error 44.17,  test loss 1.339022, test error 48.80
# Epoch   500, train loss 1.286825, train error 43.42,  test loss 1.360672, test error 49.05
# Epoch   600, train loss 1.286244, train error 44.03,  test loss 1.388063, test error 49.80
# Epoch   700, train loss 1.281666, train error 43.95,  test loss 1.389487, test error 49.15
# Epoch   800, train loss 1.286386, train error 43.55,  test loss 1.385196, test error 49.55
# Epoch   900, train loss 1.271519, train error 42.50,  test loss 1.411465, test error 50.03
# Training model with  18 hidden variables
# Epoch     0, train loss 2.187115, train error 81.25,  test loss 2.171288, test error 79.72
# Epoch   100, train loss 1.301299, train error 42.85,  test loss 1.258387, test error 46.97
# Epoch   200, train loss 1.215800, train error 40.65,  test loss 1.314154, test error 48.95
# Epoch   300, train loss 1.164626, train error 39.12,  test loss 1.381225, test error 49.45
# Epoch   400, train loss 1.141522, train error 38.58,  test loss 1.402791, test error 49.35
# Epoch   500, train loss 1.133571, train error 37.80,  test loss 1.452112, test error 49.92
# Epoch   600, train loss 1.118090, train error 37.25,  test loss 1.466098, test error 49.53
# Epoch   700, train loss 1.117490, train error 37.30,  test loss 1.481461, test error 50.25
# Epoch   800, train loss 1.118391, train error 37.62,  test loss 1.522195, test error 50.47
# Epoch   900, train loss 1.113956, train error 37.75,  test loss 1.552129, test error 50.78
# Training model with  22 hidden variables
# Epoch     0, train loss 2.180265, train error 81.10,  test loss 2.164595, test error 81.40
# Epoch   100, train loss 1.267110, train error 41.17,  test loss 1.269569, test error 46.92
# Epoch   200, train loss 1.136217, train error 37.47,  test loss 1.349183, test error 48.62
# Epoch   300, train loss 1.090769, train error 35.78,  test loss 1.417841, test error 49.35
# Epoch   400, train loss 1.061748, train error 35.00,  test loss 1.455073, test error 49.83
# Epoch   500, train loss 1.033274, train error 34.25,  test loss 1.526013, test error 50.67
# Epoch   600, train loss 1.007319, train error 33.30,  test loss 1.576608, test error 51.25
# Epoch   700, train loss 0.997844, train error 32.78,  test loss 1.597732, test error 50.65
# Epoch   800, train loss 0.984939, train error 32.82,  test loss 1.636999, test error 50.35
# Epoch   900, train loss 0.977943, train error 32.60,  test loss 1.679233, test error 50.30
# Training model with  26 hidden variables
# Epoch     0, train loss 2.215989, train error 81.90,  test loss 2.189876, test error 80.20
# Epoch   100, train loss 1.234697, train error 41.60,  test loss 1.351540, test error 50.50
# Epoch   200, train loss 1.061422, train error 35.78,  test loss 1.453944, test error 49.67
# Epoch   300, train loss 0.965258, train error 32.20,  test loss 1.610863, test error 51.33
# Epoch   400, train loss 0.945457, train error 32.18,  test loss 1.730634, test error 53.40
# Epoch   500, train loss 0.898572, train error 30.15,  test loss 1.793090, test error 53.00
# Epoch   600, train loss 0.880657, train error 29.05,  test loss 1.867242, test error 54.30
# Epoch   700, train loss 0.866432, train error 29.18,  test loss 1.943295, test error 54.60
# Epoch   800, train loss 0.853708, train error 29.03,  test loss 2.066578, test error 54.85
# Epoch   900, train loss 0.838245, train error 28.80,  test loss 2.129350, test error 55.05
# Training model with  30 hidden variables
# Epoch     0, train loss 2.097585, train error 77.88,  test loss 2.036225, test error 76.38
# Epoch   100, train loss 1.124647, train error 37.58,  test loss 1.317505, test error 47.55
# Epoch   200, train loss 0.948573, train error 30.60,  test loss 1.486068, test error 50.30
# Epoch   300, train loss 0.835800, train error 26.60,  test loss 1.670481, test error 51.03
# Epoch   400, train loss 0.790681, train error 26.03,  test loss 1.856221, test error 52.15
# Epoch   500, train loss 0.751992, train error 24.90,  test loss 2.031348, test error 52.05
# Epoch   600, train loss 0.713011, train error 23.57,  test loss 2.179323, test error 53.58
# Epoch   700, train loss 0.687285, train error 22.10,  test loss 2.325742, test error 53.33
# Epoch   800, train loss 0.672266, train error 21.80,  test loss 2.453504, test error 53.47
# Epoch   900, train loss 0.651124, train error 21.30,  test loss 2.539473, test error 53.78
# Training model with  35 hidden variables
# Epoch     0, train loss 2.095209, train error 77.72,  test loss 2.040351, test error 77.30
# Epoch   100, train loss 1.060435, train error 35.20,  test loss 1.336654, test error 48.20
# Epoch   200, train loss 0.823450, train error 26.40,  test loss 1.589085, test error 50.83
# Epoch   300, train loss 0.713199, train error 23.78,  test loss 1.929515, test error 52.50
# Epoch   400, train loss 0.608807, train error 20.75,  test loss 2.237263, test error 54.75
# Epoch   500, train loss 0.556976, train error 19.03,  test loss 2.604342, test error 54.97
# Epoch   600, train loss 0.492703, train error 16.20,  test loss 2.918746, test error 55.22
# Epoch   700, train loss 0.457915, train error 15.35,  test loss 3.237180, test error 56.03
# Epoch   800, train loss 0.441381, train error 14.30,  test loss 3.574140, test error 56.45
# Epoch   900, train loss 0.399110, train error 12.57,  test loss 3.762292, test error 56.92
# Training model with  40 hidden variables
# Epoch     0, train loss 2.109202, train error 78.90,  test loss 2.074022, test error 78.12
# Epoch   100, train loss 0.895190, train error 28.80,  test loss 1.416131, test error 47.90
# Epoch   200, train loss 0.662704, train error 21.78,  test loss 1.882502, test error 52.60
# Epoch   300, train loss 0.500667, train error 16.35,  test loss 2.434299, test error 52.00
# Epoch   400, train loss 0.399815, train error 13.43,  test loss 3.099764, test error 53.03
# Epoch   500, train loss 0.345668, train error 11.20,  test loss 3.861508, test error 53.95
# Epoch   600, train loss 0.309631, train error 10.20,  test loss 4.653522, test error 56.20
# Epoch   700, train loss 0.300910, train error 10.50,  test loss 5.284343, test error 55.80
# Epoch   800, train loss 0.292284, train error 10.18,  test loss 5.948567, test error 55.72
# Epoch   900, train loss 0.259930, train error 8.75,  test loss 6.647174, test error 56.05
# Training model with  45 hidden variables
# Epoch     0, train loss 2.142894, train error 78.57,  test loss 2.110391, test error 77.90
# Epoch   100, train loss 0.812473, train error 25.53,  test loss 1.492578, test error 49.92
# Epoch   200, train loss 0.463605, train error 14.47,  test loss 2.336027, test error 54.47
# Epoch   300, train loss 0.292566, train error 8.65,  test loss 3.550842, test error 56.67
# Epoch   400, train loss 0.213232, train error 7.25,  test loss 4.840191, test error 57.38
# Epoch   500, train loss 0.132966, train error 4.20,  test loss 6.217880, test error 57.15
# Epoch   600, train loss 0.024256, train error 0.03,  test loss 7.502331, test error 57.70
# Epoch   700, train loss 0.012542, train error 0.00,  test loss 8.477948, test error 57.38
# Epoch   800, train loss 0.008525, train error 0.00,  test loss 9.138568, test error 57.42
# Epoch   900, train loss 0.006408, train error 0.00,  test loss 9.647702, test error 57.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.132071, train error 81.20,  test loss 2.094828, test error 79.35
# Epoch   100, train loss 0.733037, train error 23.47,  test loss 1.521557, test error 48.97
# Epoch   200, train loss 0.329396, train error 9.22,  test loss 2.481947, test error 52.42
# Epoch   300, train loss 0.137498, train error 3.00,  test loss 4.066237, test error 54.35
# Epoch   400, train loss 0.029212, train error 0.03,  test loss 5.638400, test error 55.33
# Epoch   500, train loss 0.013247, train error 0.00,  test loss 6.563445, test error 55.38
# Epoch   600, train loss 0.008100, train error 0.00,  test loss 7.169280, test error 55.42
# Epoch   700, train loss 0.005778, train error 0.00,  test loss 7.630980, test error 55.53
# Epoch   800, train loss 0.004464, train error 0.00,  test loss 7.989323, test error 55.47
# Epoch   900, train loss 0.003583, train error 0.00,  test loss 8.291967, test error 55.50
# Training model with  55 hidden variables
# Epoch     0, train loss 2.082585, train error 76.93,  test loss 2.053298, test error 78.35
# Epoch   100, train loss 0.593822, train error 18.20,  test loss 1.597927, test error 49.03
# Epoch   200, train loss 0.185983, train error 3.75,  test loss 2.987435, test error 52.97
# Epoch   300, train loss 0.039666, train error 0.07,  test loss 4.557439, test error 53.60
# Epoch   400, train loss 0.013829, train error 0.00,  test loss 5.510789, test error 53.85
# Epoch   500, train loss 0.008189, train error 0.00,  test loss 6.095463, test error 53.67
# Epoch   600, train loss 0.005647, train error 0.00,  test loss 6.520192, test error 53.65
# Epoch   700, train loss 0.004185, train error 0.00,  test loss 6.851415, test error 53.85
# Epoch   800, train loss 0.003329, train error 0.00,  test loss 7.122818, test error 53.75
# Epoch   900, train loss 0.002729, train error 0.00,  test loss 7.345286, test error 53.83
# Training model with  60 hidden variables
# Epoch     0, train loss 2.049411, train error 76.47,  test loss 1.990766, test error 75.95
# Epoch   100, train loss 0.519260, train error 15.20,  test loss 1.709172, test error 50.20
# Epoch   200, train loss 0.102950, train error 1.03,  test loss 3.290606, test error 52.30
# Epoch   300, train loss 0.019001, train error 0.00,  test loss 4.591032, test error 53.17
# Epoch   400, train loss 0.009338, train error 0.00,  test loss 5.247208, test error 53.53
# Epoch   500, train loss 0.005929, train error 0.00,  test loss 5.686251, test error 53.80
# Epoch   600, train loss 0.004239, train error 0.00,  test loss 6.004104, test error 53.75
# Epoch   700, train loss 0.003262, train error 0.00,  test loss 6.263012, test error 53.90
# Epoch   800, train loss 0.002630, train error 0.00,  test loss 6.475157, test error 53.90
# Epoch   900, train loss 0.002187, train error 0.00,  test loss 6.650785, test error 53.90
# Training model with  70 hidden variables
# Epoch     0, train loss 2.063246, train error 75.05,  test loss 2.020998, test error 74.78
# Epoch   100, train loss 0.378163, train error 9.45,  test loss 1.851202, test error 51.35
# Epoch   200, train loss 0.037619, train error 0.00,  test loss 3.478702, test error 52.97
# Epoch   300, train loss 0.011739, train error 0.00,  test loss 4.281154, test error 53.30
# Epoch   400, train loss 0.006466, train error 0.00,  test loss 4.719100, test error 53.40
# Epoch   500, train loss 0.004317, train error 0.00,  test loss 5.015087, test error 53.60
# Epoch   600, train loss 0.003180, train error 0.00,  test loss 5.251516, test error 53.67
# Epoch   700, train loss 0.002490, train error 0.00,  test loss 5.435848, test error 53.58
# Epoch   800, train loss 0.002028, train error 0.00,  test loss 5.593130, test error 53.62
# Epoch   900, train loss 0.001701, train error 0.00,  test loss 5.726792, test error 53.58
# Training model with  80 hidden variables
# Epoch     0, train loss 2.046037, train error 75.45,  test loss 1.981865, test error 75.57
# Epoch   100, train loss 0.236192, train error 4.15,  test loss 2.073956, test error 51.60
# Epoch   200, train loss 0.020249, train error 0.00,  test loss 3.429296, test error 52.50
# Epoch   300, train loss 0.008081, train error 0.00,  test loss 3.989130, test error 52.75
# Epoch   400, train loss 0.004774, train error 0.00,  test loss 4.319894, test error 52.70
# Epoch   500, train loss 0.003292, train error 0.00,  test loss 4.555694, test error 52.70
# Epoch   600, train loss 0.002475, train error 0.00,  test loss 4.739760, test error 52.65
# Epoch   700, train loss 0.001964, train error 0.00,  test loss 4.887693, test error 52.55
# Epoch   800, train loss 0.001617, train error 0.00,  test loss 5.013255, test error 52.42
# Epoch   900, train loss 0.001366, train error 0.00,  test loss 5.121943, test error 52.47
# Training model with  90 hidden variables
# Epoch     0, train loss 2.012519, train error 74.10,  test loss 1.941467, test error 73.62
# Epoch   100, train loss 0.151560, train error 1.15,  test loss 2.229488, test error 52.47
# Epoch   200, train loss 0.015332, train error 0.00,  test loss 3.361079, test error 52.30
# Epoch   300, train loss 0.006720, train error 0.00,  test loss 3.819932, test error 52.15
# Epoch   400, train loss 0.004079, train error 0.00,  test loss 4.098560, test error 52.08
# Epoch   500, train loss 0.002862, train error 0.00,  test loss 4.298297, test error 52.17
# Epoch   600, train loss 0.002176, train error 0.00,  test loss 4.453572, test error 52.03
# Epoch   700, train loss 0.001738, train error 0.00,  test loss 4.583583, test error 52.10
# Epoch   800, train loss 0.001438, train error 0.00,  test loss 4.691191, test error 52.10
# Epoch   900, train loss 0.001221, train error 0.00,  test loss 4.785801, test error 52.20
# Training model with 100 hidden variables
# Epoch     0, train loss 1.973582, train error 73.12,  test loss 1.907836, test error 73.22
# Epoch   100, train loss 0.086113, train error 0.15,  test loss 2.148224, test error 48.58
# Epoch   200, train loss 0.012273, train error 0.00,  test loss 2.962140, test error 49.12
# Epoch   300, train loss 0.005684, train error 0.00,  test loss 3.303436, test error 49.20
# Epoch   400, train loss 0.003546, train error 0.00,  test loss 3.518647, test error 49.35
# Epoch   500, train loss 0.002530, train error 0.00,  test loss 3.678466, test error 49.25
# Epoch   600, train loss 0.001935, train error 0.00,  test loss 3.802419, test error 49.25
# Epoch   700, train loss 0.001557, train error 0.00,  test loss 3.905854, test error 49.35
# Epoch   800, train loss 0.001294, train error 0.00,  test loss 3.992103, test error 49.38
# Epoch   900, train loss 0.001101, train error 0.00,  test loss 4.068422, test error 49.30
# Training model with 120 hidden variables
# Epoch     0, train loss 1.977603, train error 73.57,  test loss 1.924781, test error 75.18
# Epoch   100, train loss 0.053052, train error 0.03,  test loss 2.188279, test error 50.35
# Epoch   200, train loss 0.009754, train error 0.00,  test loss 2.829859, test error 50.53
# Epoch   300, train loss 0.004777, train error 0.00,  test loss 3.119187, test error 50.58
# Epoch   400, train loss 0.003054, train error 0.00,  test loss 3.304139, test error 50.62
# Epoch   500, train loss 0.002201, train error 0.00,  test loss 3.439919, test error 50.55
# Epoch   600, train loss 0.001697, train error 0.00,  test loss 3.546902, test error 50.75
# Epoch   700, train loss 0.001372, train error 0.00,  test loss 3.636021, test error 50.62
# Epoch   800, train loss 0.001145, train error 0.00,  test loss 3.711404, test error 50.75
# Epoch   900, train loss 0.000978, train error 0.00,  test loss 3.777377, test error 50.75
# Training model with 140 hidden variables
# Epoch     0, train loss 1.965524, train error 72.03,  test loss 1.887541, test error 72.28
# Epoch   100, train loss 0.036854, train error 0.00,  test loss 2.110115, test error 48.83
# Epoch   200, train loss 0.008164, train error 0.00,  test loss 2.587216, test error 48.78
# Epoch   300, train loss 0.004172, train error 0.00,  test loss 2.812734, test error 48.47
# Epoch   400, train loss 0.002707, train error 0.00,  test loss 2.961067, test error 48.60
# Epoch   500, train loss 0.001969, train error 0.00,  test loss 3.071597, test error 48.62
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.158977, test error 48.62
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.232269, test error 48.75
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.294472, test error 48.78
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.348827, test error 48.83
# Training model with 160 hidden variables
# Epoch     0, train loss 1.938502, train error 70.07,  test loss 1.885894, test error 73.55
# Epoch   100, train loss 0.028548, train error 0.00,  test loss 2.135004, test error 48.50
# Epoch   200, train loss 0.007150, train error 0.00,  test loss 2.543379, test error 48.78
# Epoch   300, train loss 0.003772, train error 0.00,  test loss 2.745583, test error 49.03
# Epoch   400, train loss 0.002482, train error 0.00,  test loss 2.878546, test error 49.10
# Epoch   500, train loss 0.001821, train error 0.00,  test loss 2.978263, test error 49.03
# Epoch   600, train loss 0.001420, train error 0.00,  test loss 3.055991, test error 48.90
# Epoch   700, train loss 0.001157, train error 0.00,  test loss 3.123629, test error 48.97
# Epoch   800, train loss 0.000971, train error 0.00,  test loss 3.179908, test error 49.05
# Epoch   900, train loss 0.000834, train error 0.00,  test loss 3.229700, test error 48.92
# Training model with 180 hidden variables
# Epoch     0, train loss 1.946257, train error 72.57,  test loss 1.870585, test error 72.43
# Epoch   100, train loss 0.024043, train error 0.00,  test loss 2.066845, test error 48.40
# Epoch   200, train loss 0.006610, train error 0.00,  test loss 2.432592, test error 48.55
# Epoch   300, train loss 0.003542, train error 0.00,  test loss 2.611286, test error 48.60
# Epoch   400, train loss 0.002346, train error 0.00,  test loss 2.731500, test error 48.83
# Epoch   500, train loss 0.001726, train error 0.00,  test loss 2.823436, test error 48.78
# Epoch   600, train loss 0.001353, train error 0.00,  test loss 2.895442, test error 48.78
# Epoch   700, train loss 0.001105, train error 0.00,  test loss 2.956483, test error 48.85
# Epoch   800, train loss 0.000929, train error 0.00,  test loss 3.008336, test error 48.90
# Epoch   900, train loss 0.000798, train error 0.00,  test loss 3.054124, test error 48.95
# Training model with 200 hidden variables
# Epoch     0, train loss 1.896029, train error 69.28,  test loss 1.838565, test error 70.65
# Epoch   100, train loss 0.021013, train error 0.00,  test loss 1.971305, test error 47.28
# Epoch   200, train loss 0.006056, train error 0.00,  test loss 2.283620, test error 47.30
# Epoch   300, train loss 0.003293, train error 0.00,  test loss 2.445581, test error 47.20
# Epoch   400, train loss 0.002196, train error 0.00,  test loss 2.553531, test error 47.17
# Epoch   500, train loss 0.001623, train error 0.00,  test loss 2.634060, test error 47.03
# Epoch   600, train loss 0.001275, train error 0.00,  test loss 2.699146, test error 47.00
# Epoch   700, train loss 0.001043, train error 0.00,  test loss 2.753790, test error 46.92
# Epoch   800, train loss 0.000878, train error 0.00,  test loss 2.799851, test error 46.90
# Epoch   900, train loss 0.000756, train error 0.00,  test loss 2.841550, test error 46.90
# Training model with 250 hidden variables
# Epoch     0, train loss 1.909635, train error 69.38,  test loss 1.815313, test error 69.45
# Epoch   100, train loss 0.017095, train error 0.00,  test loss 1.896435, test error 47.17
# Epoch   200, train loss 0.005408, train error 0.00,  test loss 2.150003, test error 46.92
# Epoch   300, train loss 0.002999, train error 0.00,  test loss 2.283832, test error 46.95
# Epoch   400, train loss 0.002026, train error 0.00,  test loss 2.374275, test error 47.00
# Epoch   500, train loss 0.001508, train error 0.00,  test loss 2.443665, test error 47.00
# Epoch   600, train loss 0.001190, train error 0.00,  test loss 2.499475, test error 46.97
# Epoch   700, train loss 0.000978, train error 0.00,  test loss 2.546594, test error 47.03
# Epoch   800, train loss 0.000826, train error 0.00,  test loss 2.586030, test error 46.90
# Epoch   900, train loss 0.000712, train error 0.00,  test loss 2.620874, test error 46.88
# Training model with 300 hidden variables
# Epoch     0, train loss 1.852375, train error 66.68,  test loss 1.770232, test error 67.53
# Epoch   100, train loss 0.014189, train error 0.00,  test loss 1.830961, test error 46.12
# Epoch   200, train loss 0.004764, train error 0.00,  test loss 2.041249, test error 46.30
# Epoch   300, train loss 0.002708, train error 0.00,  test loss 2.154935, test error 46.42
# Epoch   400, train loss 0.001847, train error 0.00,  test loss 2.231265, test error 46.50
# Epoch   500, train loss 0.001383, train error 0.00,  test loss 2.290715, test error 46.42
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.338608, test error 46.38
# Epoch   700, train loss 0.000903, train error 0.00,  test loss 2.378418, test error 46.30
# Epoch   800, train loss 0.000765, train error 0.00,  test loss 2.413276, test error 46.30
# Epoch   900, train loss 0.000661, train error 0.00,  test loss 2.443923, test error 46.28
# Training model with 400 hidden variables
# Epoch     0, train loss 1.850695, train error 66.18,  test loss 1.790255, test error 68.18
# Epoch   100, train loss 0.011936, train error 0.00,  test loss 1.771134, test error 45.28
# Epoch   200, train loss 0.004224, train error 0.00,  test loss 1.950597, test error 45.38
# Epoch   300, train loss 0.002443, train error 0.00,  test loss 2.047456, test error 45.12
# Epoch   400, train loss 0.001682, train error 0.00,  test loss 2.115059, test error 45.00
# Epoch   500, train loss 0.001267, train error 0.00,  test loss 2.167353, test error 44.97
# Epoch   600, train loss 0.001009, train error 0.00,  test loss 2.209675, test error 44.88
# Epoch   700, train loss 0.000833, train error 0.00,  test loss 2.245463, test error 44.83
# Epoch   800, train loss 0.000707, train error 0.00,  test loss 2.276340, test error 44.80
# Epoch   900, train loss 0.000612, train error 0.00,  test loss 2.303166, test error 44.80

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
