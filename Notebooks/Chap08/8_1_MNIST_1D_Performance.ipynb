# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirui-peng/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-icl5wx5q
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-icl5wx5q
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=f7d4818bfeb43e79825a7bc0b6b54353d6fcb5df58ef49fdce7bc43d57854206
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jnobtd9g/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.589670, train error 61.42,  test loss 1.675514, test error 66.00
# Epoch     1, train loss 1.339725, train error 47.90,  test loss 1.494976, test error 58.10
# Epoch     2, train loss 1.154636, train error 42.08,  test loss 1.345666, test error 52.80
# Epoch     3, train loss 1.012993, train error 35.32,  test loss 1.239427, test error 48.30
# Epoch     4, train loss 0.921852, train error 32.88,  test loss 1.218171, test error 46.20
# Epoch     5, train loss 0.781320, train error 26.32,  test loss 1.095874, test error 42.10
# Epoch     6, train loss 0.724438, train error 25.53,  test loss 1.144101, test error 44.90
# Epoch     7, train loss 0.631284, train error 21.45,  test loss 1.113372, test error 41.10
# Epoch     8, train loss 0.558175, train error 19.43,  test loss 1.047177, test error 37.80
# Epoch     9, train loss 0.501252, train error 16.20,  test loss 1.122407, test error 39.40
# Epoch    10, train loss 0.403854, train error 11.65,  test loss 1.017695, test error 38.10
# Epoch    11, train loss 0.365564, train error 9.62,  test loss 1.058290, test error 38.10
# Epoch    12, train loss 0.340208, train error 9.53,  test loss 1.084751, test error 38.60
# Epoch    13, train loss 0.308336, train error 8.05,  test loss 1.104467, test error 37.90
# Epoch    14, train loss 0.277259, train error 6.18,  test loss 1.100696, test error 37.90
# Epoch    15, train loss 0.252861, train error 5.53,  test loss 1.096281, test error 38.40
# Epoch    16, train loss 0.239767, train error 5.22,  test loss 1.135936, test error 37.50
# Epoch    17, train loss 0.219059, train error 4.75,  test loss 1.167006, test error 37.30
# Epoch    18, train loss 0.188851, train error 3.20,  test loss 1.182499, test error 37.90
# Epoch    19, train loss 0.179664, train error 2.82,  test loss 1.191903, test error 37.80
# Epoch    20, train loss 0.150632, train error 1.75,  test loss 1.199407, test error 37.40
# Epoch    21, train loss 0.142618, train error 1.68,  test loss 1.199564, test error 37.60
# Epoch    22, train loss 0.135480, train error 1.25,  test loss 1.217639, test error 37.60
# Epoch    23, train loss 0.126651, train error 0.95,  test loss 1.217140, test error 36.50
# Epoch    24, train loss 0.121330, train error 0.95,  test loss 1.217415, test error 37.40
# Epoch    25, train loss 0.114633, train error 0.57,  test loss 1.242346, test error 36.50
# Epoch    26, train loss 0.107964, train error 0.60,  test loss 1.247657, test error 37.00
# Epoch    27, train loss 0.103881, train error 0.60,  test loss 1.272107, test error 36.60
# Epoch    28, train loss 0.100260, train error 0.50,  test loss 1.265095, test error 36.80
# Epoch    29, train loss 0.095698, train error 0.43,  test loss 1.280197, test error 37.20
# Epoch    30, train loss 0.088767, train error 0.28,  test loss 1.280001, test error 36.40
# Epoch    31, train loss 0.086967, train error 0.25,  test loss 1.277745, test error 35.80
# Epoch    32, train loss 0.084419, train error 0.20,  test loss 1.292206, test error 36.30
# Epoch    33, train loss 0.082499, train error 0.20,  test loss 1.294171, test error 36.20
# Epoch    34, train loss 0.080857, train error 0.18,  test loss 1.302305, test error 37.00
# Epoch    35, train loss 0.078660, train error 0.10,  test loss 1.306809, test error 36.00
# Epoch    36, train loss 0.076784, train error 0.10,  test loss 1.310339, test error 36.40
# Epoch    37, train loss 0.075436, train error 0.12,  test loss 1.317887, test error 36.50
# Epoch    38, train loss 0.073592, train error 0.10,  test loss 1.319753, test error 36.20
# Epoch    39, train loss 0.071769, train error 0.12,  test loss 1.323561, test error 36.10
# Epoch    40, train loss 0.070798, train error 0.10,  test loss 1.331027, test error 36.00
# Epoch    41, train loss 0.070096, train error 0.07,  test loss 1.334409, test error 35.90
# Epoch    42, train loss 0.069250, train error 0.10,  test loss 1.331407, test error 36.20
# Epoch    43, train loss 0.068526, train error 0.07,  test loss 1.337339, test error 35.90
# Epoch    44, train loss 0.067746, train error 0.07,  test loss 1.336486, test error 36.50
# Epoch    45, train loss 0.066998, train error 0.07,  test loss 1.343778, test error 36.20
# Epoch    46, train loss 0.066285, train error 0.07,  test loss 1.344493, test error 36.70
# Epoch    47, train loss 0.065554, train error 0.07,  test loss 1.347646, test error 36.70
# Epoch    48, train loss 0.065023, train error 0.05,  test loss 1.350004, test error 35.90
# Epoch    49, train loss 0.064318, train error 0.05,  test loss 1.350201, test error 36.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
